# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
x_max=10
dx=0.1

x=np.array([i for i in range(0,int(x_max/dx))])
y=np.array([i*i*i for i in range(0,int(x_max/dx))])

dy=y[1:]-y[:int(x_max/dx)-1]
dy1=dy[1:]-dy[:(int(x_max/dx)-2)]

#dy1=np.array([3*i*i for i in range(0,int(x_max/dx))])
dy2=np.array([6*i for i in range(0,int(x_max/dx))])
#plt.plot(x[1:],dy,c='red')
plt.scatter(x,dy2,c='blue')

plt.plot(x[2:],dy1,c='black')

# %%
plt.plot(x, c='red')
plt.plot(y, c='blue')
